# %%
import pandas as pd

# %%
books_df = pd.read_csv('first_successful_gain.csv')
books_df
# Out:
#                                                  title  \
# 0    Александр Карелин: Правильное питание при недо...
# 1    Александр Румянцев: Правильное питание при бол...
# 2    Анастасия Артемова: Крапива  исцеляющая и омол...
# 3    Генрих Ужегов: Зона особого внимания: Биоритмы...
# 4    Надежда Семенова: 500 лучших рецептов раздельн...
# ..                                                 ...
# 995                    Олег Филатов: Лечение облепихой
# 996  Сергей Лукьяненко: Ночной дозор. Сумеречный До...
# 997  Владимир Гольдич: Алгебра: Решение уравнений и...
# 998  Тетрадь с 2 смен. блоками А5 80л. с разделителями
# 999                      Мигель Делибес: Еретик: Роман
#
#                            author   publisher  year               isbn  \
# 0               Карелин Александр        Диля  2002      5-8174-0256-4
# 1    Румянцев Александр Шаликович        Диля  2009             скрыть
# 2              Артемова Анастасия        Диля  2001      5-8174-0229-7
# ...

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   title            1000 non-null   object
#  1   author           1000 non-null   object
#  2   publisher        1000 non-null   object
#  3   year             1000 non-null   int64
#  4   isbn             1000 non-null   object
#  5   cover_image_url  1000 non-null   object
#  6   annotation       710 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %%
empty_author = books_df[books_df['author'] == '-']
empty_author.info()
empty_author
# Out:
#                                                  title author     publisher  \
# 12   Гражданский процессуальный кодекс РФ от 14.11....      -          Диля
# 14            Уголовный кодекс РФ от 25 июля 2002 года      -          Диля
# 16                                 Конституция РФ/Диля      -          Диля
# 17      Решения Конституционного Суда РФ 2000-2002 год      -          Диля
# 18      Решения Конституционного Суда РФ 1997-1999 год      -          Диля
# ..                                                 ...    ...           ...
# 982                          Атлас для самых маленьких      -        Росмэн
# 983        Любимые стихи для самых маленьких (красная)      -        Росмэн
# 986               Готовимся к школе. Для детей 5-6 лет      -        Росмэн
# 990             Б-474/8 Марта/открытка вырубка двойная      -  ФЕРО-Графика
# 998  Тетрадь с 2 смен. блоками А5 80л. с разделителями      -    Бумизделия
#
# ...
