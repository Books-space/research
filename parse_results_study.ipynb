# %%
import pandas as pd

# %%
books_df = pd.read_csv('third_successful_gain.csv')
books_df
# Out:
#          id                                              title  \
# 0     30000                             Приусадебные постройки
# 1     30016  Александр Румянцев: Правильное питание при бол...
# 2     30025  Генрих Ужегов: Зона особого внимания: Биоритмы...
# 3     30035  Анастасия Артемова: Одуванчик  исцеляющий и ом...
# 4     30040  Генрих Ужегов: Зона особого внимания: Ревматиз...
# ...     ...                                                ...
# 2995  50982           Скиннер, Клииз: Жизнь и как в ней выжить
# 2996  50983  Сборник типовых инструкций по охране труда при...
# 2997  50990  Питер Клейтон: Секреты языка тела. Учитесь вид...
# 2998  50991          Майкл Джордан: Будда: Его жизнь в образах
# 2999  50993         Вячеслав Шпаковский: Рыцари. Замки. Оружие
#
#                             author                      publisher  year  \
# 0                              NaN                           Диля  2005
# ...

# %%
books_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3000 non-null   int64
#  1   title            3000 non-null   object
#  2   author           2360 non-null   object
#  3   publisher        3000 non-null   object
#  4   year             3000 non-null   int64
#  5   isbn             3000 non-null   object
#  6   cover_image_url  3000 non-null   object
#  7   annotation       2536 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 187.6+ KB

# %%
empty_author = books_df[books_df['author'].isnull()]
empty_author.info()
empty_author
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 640 entries, 0 to 2996
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               640 non-null    int64
#  1   title            640 non-null    object
#  2   author           0 non-null      object
#  3   publisher        640 non-null    object
#  4   year             640 non-null    int64
#  5   isbn             640 non-null    object
#  6   cover_image_url  640 non-null    object
#  7   annotation       487 non-null    object
# dtypes: int64(2), object(6)
# memory usage: 45.0+ KB
#          id                                              title author  \
# 0     30000                             Приусадебные постройки    NaN
# 8     30068           Налоговый кодекс РФ от 24 июля 2002 года    NaN
# 12    30082  Уголовно- процессуальный кодекс РФ от 18.12.20...    NaN
# 15    30093     Решения Конституционного Суда РФ 1997-1999 год    NaN
# ...

# %%
l = len('5-88503-106-1')
ok_isbn_df = books_df[books_df['isbn'].str.len() > 9].sort_values('author')
ok_isbn_df.info()
ok_publisher = ok_isbn_df[ok_isbn_df['publisher'] != 'UNKNOWN']
ok_publisher.info()
ok_publisher
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 2464 to 2996
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3000 non-null   int64
#  1   title            3000 non-null   object
#  2   author           2360 non-null   object
#  3   publisher        3000 non-null   object
#  4   year             3000 non-null   int64
#  5   isbn             3000 non-null   object
#  6   cover_image_url  3000 non-null   object
#  7   annotation       2536 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 210.9+ KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 2464 to 2996
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3000 non-null   int64
#  1   title            3000 non-null   object
#  2   author           2360 non-null   object
# ...

# %%
ok_publisher = ok_isbn_df[ok_isbn_df['cover_image_url'] != 'https://img.labirint.ru/design/emptycover.svg']
ok_publisher.info()
ok_publisher
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3000 entries, 2464 to 2996
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               3000 non-null   int64
#  1   title            3000 non-null   object
#  2   author           2360 non-null   object
#  3   publisher        3000 non-null   object
#  4   year             3000 non-null   int64
#  5   isbn             3000 non-null   object
#  6   cover_image_url  3000 non-null   object
#  7   annotation       2536 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 210.9+ KB
#          id                                              title  \
# 2464  47815                                      Таро секретов
# 231   31466  Банана Ёсимото: Кухня: Маленький роман; Тень п...
# 295   31931          Чингиз Абдуллаев: В ожидании Апокалипсиса
# 1496  40883             Галина Абеляшева: Импрессионизм/Росмэн
# ...

# %%
l = len('5-88503-106-1')
hide_isbn_df = books_df[books_df['isbn'] == 'скрыть']
hide_isbn_df.info()
hide_isbn_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               0 non-null      int64
#  1   title            0 non-null      object
#  2   author           0 non-null      object
#  3   publisher        0 non-null      object
#  4   year             0 non-null      int64
#  5   isbn             0 non-null      object
#  6   cover_image_url  0 non-null      object
#  7   annotation       0 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 0.0+ bytes
# Empty DataFrame
# Columns: [id, title, author, publisher, year, isbn, cover_image_url, annotation]
# Index: []

# %%
boomizdeliya = books_df[books_df['publisher'] == 'Бумизделия']
boomizdeliya.info()
boomizdeliya
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               0 non-null      int64
#  1   title            0 non-null      object
#  2   author           0 non-null      object
#  3   publisher        0 non-null      object
#  4   year             0 non-null      int64
#  5   isbn             0 non-null      object
#  6   cover_image_url  0 non-null      object
#  7   annotation       0 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 0.0+ bytes
# Empty DataFrame
# Columns: [id, title, author, publisher, year, isbn, cover_image_url, annotation]
# Index: []

# %%
unique_authors = books_df['author'].unique()
print(len(unique_authors))
unique_authors
# Out:
# 1745
# array([nan, 'Румянцев Александр Шаликович', 'Ужегов Генрих Николаевич',
#        ..., 'Клейтон Питер', 'Джордан Майкл',
#        'Шпаковский Вячеслав Олегович'], dtype=object)

# %%
unique_publishers = books_df['publisher'].unique()
print(len(unique_publishers))
print('\n'.join(sorted(unique_publishers)))
# Out:
# 162
# BHV
# АСС-Центр
# АСТ
# АСТ-Пресс
# Аввалон-Ло Скарабео
# Ад Маргинем
# Аделант
# Азбука
# Аиф-Принт
# Айрис-Пресс
# Академия Развития
# Алтей
# Альпина Бизнес Букс
# Альпина Паблишер
# Альфа-книга
# Амфора
# Андра
# Арт-родник
# Арус
# Ассоциация 21 век
# Астрель
# Атберг 98
# Б.С.Г.- Пресс
# Баласс
# Бао-Пресс
# Баро-Пресс
# Белый город
# Бук Хаус
# Була
# Вагриус
# Вако
# Весь
# Вече
# Вита
# Вита-Пресс
# Владис
# Владос
# Внешсигма
# Высшая школа
# Гелеос
# Генжер
# Герион
# Гранд-Фаир
# Дельта
# Детиздат
# Детство-Пресс
# Диля
# Дом Федорова
# За рулем
# ИД МВМ
# ИД Рученькиных
# ИД Третий Рим
# Изд-во "ИН"
# Изд-во "Радуга"
# Изд-во Жигульского
# Изд-во Института Психотерапии
# Инапресс
# Иностранка
# Интерпрессервис
# Искатель
# КМК
# Капля
# Карапуз
# Кладезь
# Классикс Стиль
# Книжный дом
# Кристалл
# Крылов
# Лабиринт
# Лада/Москва
# Легион-Автодата
# Ленинградское издательство
# Лимбус-Пресс
# Лист
# Литера
# Литур
# Локид
# МСП
# Майор
# Максима ИЦ
# Максима-Н
# ...

# %%
unique_isbns = books_df['isbn'].unique()
print(len(unique_isbns))
print('\n'.join(sorted(unique_isbns)))
# Out:
# 3000
# 0132-540X-5
# 0132-540XX
# 04607-0043
# 05939-237-4545
# 3-8228-7150-8
# 3-8228-7151-6
# 300-0-0000-42739
# 460-6-8260-0001-7
# 4602607000436
# 4602607001686
# 4602607001754
# 4602607001822
# 4602607001853
# 4602607002621
# 4602607003086
# 4602607004243
# 4602698001213
# 4602698001978
# 4602698002319
# 4606826000192
# 5--462-00012-X
# 5-04-000380-3
# 5-04-000423-0
# 5-04-000736-1
# 5-04-000805-8
# 5-04-003657-4
# 5-04-006594-9
# 5-05-005043-X
# 5-05-005205-X
# 5-05-005241-6
# 5-05-005242-4
# 5-05-005274-2
# 5-05-005301-3
# 5-05-005338-2
# 5-05-005408-7
# 5-05-005440-0
# 5-05-005470-2
# 5-05-005520-2
# 5-05-005521-0
# 5-05-005534-2
# 5-05-005554-7
# 5-05-005625-X
# 5-05-005660-8
# 5-05-005668-3
# 5-05-005796-5
# 5-05-005804-X
# 5-05-005833-3
# 5-05-005846-5
# 5-05-005857-0
# 5-05-005932-1
# 5-05-005946-1
# 5-05-005961-5
# 5-05-005966-6
# 5-05-005977-1
# 5-05-005985-2
# 5-05-005987-9
# 5-05-005999-2
# 5-05-006000-1
# 5-09-010398-4
# 5-09-011292-4
# 5-09-011818-3
# 5-09-011983-X
# ...

# %%
wierd_isbns_str = '''752
0000025
00035
0004022
0005028
0005037
0005042
0005107
0005142
0005147
0012053
0012072
0012192
0012193
0012212
0132-5190
0132-5193
065326-01
065326-07
065326-14
1106
1139к
1245г
124г
1295к
1519с
1647
1668л
1729-4614
1808
1990
2305
2343
25779-01
3475347
36583
37465
396л
3Т-823
3Т-830
4576
474
48/7
648л
655л
733л
75664
756756
779с
796-1-7
884с
95869
TZ1
TZ2010
bfg2100
tv18
Е-170
Е-172
М-198
М41802
ПО-2
РА-122
РА1616
РА2102
СО5/1800
СТ-300
с1336
с2010
скрыть
'''
wierd_isbns = wierd_isbns_str.split('\n')
print(wierd_isbns)
# Out:
# ['752', '0000025', '00035', '0004022', '0005028', '0005037', '0005042', '0005107', '0005142', '0005147', '0012053', '0012072', '0012192', '0012193', '0012212', '0132-5190', '0132-5193', '065326-01', '065326-07', '065326-14', '1106', '1139к', '1245г', '124г', '1295к', '1519с', '1647', '1668л', '1729-4614', '1808', '1990', '2305', '2343', '25779-01', '3475347', '36583', '37465', '396л', '3Т-823', '3Т-830', '4576', '474', '48/7', '648л', '655л', '733л', '75664', '756756', '779с', '796-1-7', '884с', '95869', 'TZ1', 'TZ2010', 'bfg2100', 'tv18', 'Е-170', 'Е-172', 'М-198', 'М41802', 'ПО-2', 'РА-122', 'РА1616', 'РА2102', 'СО5/1800', 'СТ-300', 'с1336', 'с2010', 'скрыть', '']

# %%
wierd_isbns_books = books_df[books_df['isbn'].isin(wierd_isbns)]
wierd_isbns_books.info()
wierd_isbns_books
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9 entries, 219 to 919
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               9 non-null      int64
#  1   title            9 non-null      object
#  2   author           9 non-null      object
#  3   publisher        9 non-null      object
#  4   year             9 non-null      int64
#  5   isbn             9 non-null      object
#  6   cover_image_url  9 non-null      object
#  7   annotation       4 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 648.0+ bytes
#         id                                              title  \
# 219  31248  Сельма Лагерлеф: Путешествие Нильса с дикими г...
# 340  32019                            Кроссворды,игры,загадки
# 343  32041                                   Русские частушки
# 408  32430    Микки Маус 38/2003/еженедельный журнал комиксов
# ...

# %%
ferografika = books_df[books_df['publisher'] == 'ФЕРО-Графика']
ferografika.info()
ferografika
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 997 to 997
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1 non-null      int64
#  1   title            1 non-null      object
#  2   author           1 non-null      object
#  3   publisher        1 non-null      object
#  4   year             1 non-null      int64
#  5   isbn             1 non-null      object
#  6   cover_image_url  1 non-null      object
#  7   annotation       0 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 72.0+ bytes
#         id                                title author     publisher  year  \
# 997  36600  Е-501/С праздником/открытка двойная      -  ФЕРО-Графика  2004
#
#       isbn                                cover_image_url annotation
# 997  Е-501  https://img.labirint.ru/design/emptycover.svg        NaN

# %%
wierd_isbns_grps = books_df[books_df['isbn'].isin(wierd_isbns)].groupby('isbn').size()
wierd_isbns_grps
# Out:
# isbn
# 0005037      1
# 0005142      1
# 0012072      1
# 0132-5193    1
# 1106         1
# 1519с        1
# 1647         1
# 1990         1
# 884с         1
# dtype: int64

# %%
unknown_publisher_books = books_df[books_df['author'] == 'Ёсимото Банана']
unknown_publisher_books.info()
unknown_publisher_books
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1 entries, 231 to 231
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1 non-null      int64
#  1   title            1 non-null      object
#  2   author           1 non-null      object
#  3   publisher        1 non-null      object
#  4   year             1 non-null      int64
#  5   isbn             1 non-null      object
#  6   cover_image_url  1 non-null      object
#  7   annotation       1 non-null      object
# dtypes: int64(2), object(6)
# memory usage: 72.0+ bytes
#         id                                              title          author  \
# 231  31466  Банана Ёсимото: Кухня: Маленький роман; Тень п...  Ёсимото Банана
#
#     publisher  year           isbn  \
# 231    Амфора  2002  5-94278-215-6
#
#                                        cover_image_url  \
# 231  https://img4.labirint.ru/rc/c0e57f021d3ded2efa...
#
# ...
